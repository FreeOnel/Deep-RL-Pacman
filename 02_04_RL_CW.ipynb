# %% [markdown]
# <a href="https://colab.research.google.com/github/FreeOnel/Deep-RL-Pacman/blob/main/02_04_RL_CW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Run this code block to install relevant modules
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install -U colabgymrender
# Out:
# Collecting colabgymrender
#   Downloading https://files.pythonhosted.org/packages/b2/97/eab3f4ef460cc79b811c37c3be2d05967696605774868b6556e04e6ae6f8/colabgymrender-1.0.8.tar.gz
# Requirement already satisfied, skipping upgrade: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender) (0.2.3.5)
# Requirement already satisfied, skipping upgrade: ipython in /usr/local/lib/python3.7/dist-packages (from colabgymrender) (5.5.0)
# Requirement already satisfied, skipping upgrade: opencv-python in /usr/local/lib/python3.7/dist-packages (from colabgymrender) (4.1.2.30)
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/19/88/7a198a5ee3baa3d547f5a49574cd8c3913b216f5276b690b028f89ffb325/PyVirtualDisplay-2.1-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (1.19.5)
# Requirement already satisfied, skipping upgrade: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (4.4.2)
# Requirement already satisfied, skipping upgrade: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (4.41.1)
# Requirement already satisfied, skipping upgrade: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (2.4.1)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (4.8.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (5.0.5)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (1.0.18)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (54.2.0)
# Requirement already satisfied, skipping upgrade: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (0.8.1)
# Requirement already satisfied, skipping upgrade: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (2.6.1)
# Requirement already satisfied, skipping upgrade: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (0.7.5)
# Collecting EasyProcess
#   Downloading https://files.pythonhosted.org/packages/48/3c/75573613641c90c6d094059ac28adb748560d99bd27ee6f80cce398f404e/EasyProcess-0.3-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender) (7.1.2)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython->colabgymrender) (0.7.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.2->ipython->colabgymrender) (0.2.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->colabgymrender) (0.2.5)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->colabgymrender) (1.15.0)
# Building wheels for collected packages: colabgymrender
#   Building wheel for colabgymrender (setup.py) ... done
#   Created wheel for colabgymrender: filename=colabgymrender-1.0.8-cp37-none-any.whl size=2511 sha256=5550998d8603302d0fe9870d5a12bb4ebe238d2751dfd0484880a80ecdb459ee
#   Stored in directory: /root/.cache/pip/wheels/8a/d1/e8/ef1d4f6e536cc6b965b28c859ccd2a7f7ab123b94ef4007712
# Successfully built colabgymrender
# Installing collected packages: EasyProcess, pyvirtualdisplay, colabgymrender
# Successfully installed EasyProcess-0.3 colabgymrender-1.0.8 pyvirtualdisplay-2.1

# %%
import numpy as np
import tensorflow as tf
import random
import matplotlib.pyplot as plt
import pickle

# Initialise environment and run test recording
import gym
from colabgymrender.recorder import Recorder

env = gym.make("MsPacman-v0")

def sample(env):
  directory = './video'
  env = Recorder(env, directory)

  observation = env.reset()
  terminal = False
  while not terminal:
    action = env.action_space.sample()
    observation, reward, terminal, info = env.step(action)
  
  return env

#sample(env).play()
# Out:
# 100%|█████████▉| 714/715 [00:00<00:00, 1298.76it/s]
# <video autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video>

# %%
from PIL import Image

# Image pre processing, following the steps outlined by deepmind, 2013
def preprocess(observation):

  # Create Image object from numpy array
  image = Image.fromarray(observation)

  # Convert from RGB to grayscale
  image = image.convert('L')

  # Downsize from 210x160 to 110x84
  image = image.resize((84,110))

  # Crop to playing area only (84x84)
  image = image.crop((0,0,84,84))

  return np.array(image)

#preprocess(observation)
#Image.fromarray(observation)

# %%
color = np.array([210, 164, 74]).mean()

#prepro (210, 160, 3) uint8 frame into 7040 (88x80) 1D float vector 

def preprocess_observation(obs):

    # Crop and resize the image
    img = obs[1:176:2, ::2]

    # Convert the image to greyscale
    img = img.mean(axis=2)

    # Improve image contrast
    img[img==color] = 0

    # Next we normalize the image from -1 to +1
    img = (img - 128) / 128 - 1

    return img.reshape(88,80,1)

# %%
# Define Q-Network 

n_outputs = env.action_space.n

def q_network(X, name_scope):

  initializer = tf.compat.v1.keras.initializers.VarianceScaling(scale=2.0)

  with tf.compat.v1.variable_scope(name_scope, reuse=tf.compat.v1.AUTO_REUSE) as scope:

    layer_1 = tf.compat.v1.layers.conv2d(X, 32, kernel_size=(8,8), strides=(4,4), padding='SAME', kernel_initializer=initializer, activation=tf.nn.relu)

    layer_2 = tf.compat.v1.layers.conv2d(layer_1, 64, kernel_size=(4,4), strides=(2,2), padding='SAME', kernel_initializer=initializer, activation=tf.nn.relu)

    layer_3 = tf.compat.v1.layers.conv2d(layer_2, 64, kernel_size=(3,3), strides=(1,1), padding='SAME', kernel_initializer=initializer, activation=tf.nn.relu)

    flat = tf.compat.v1.layers.Flatten()(layer_3)

    fc = tf.compat.v1.layers.Dense(128, kernel_initializer=initializer, activation='relu')(flat)

    output = tf.compat.v1.layers.Dense(n_outputs, activation=None, kernel_initializer=initializer)(fc)

    vars = {v.name[len(scope.name):]: v for v in tf.compat.v1.get_collection(key=tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=scope.name)}
  
  return vars, output

# %%
# Copied parameters from article (change later?)
num_episodes = 800
batch_size = 48
input_shape = (None, 88, 80, 1)
#Recall shape is img.reshape(88,80,1)
learning_rate = 0.001
X_shape = (None, 88, 80, 1)
discount_factor = 0.97
global_step = 0
copy_steps = 100
steps_train = 4
start_steps = 2000

# %%
logdir = 'logs'
tf.compat.v1.reset_default_graph()

# Now we define the placeholder for our input i.e game state
tf.compat.v1.disable_eager_execution()
X = tf.compat.v1.placeholder(tf.float32, shape=X_shape)

# we define a boolean called in_training_model to toggle the training
in_training_mode = tf.compat.v1.placeholder(tf.bool)

# %%
mainQ, mainQ_outputs = q_network(X,'mainQ')

# %%
# Epsilon Greedy Policy

epsilon = 0.5
eps_min = 0.05
eps_max = 1.0
eps_decay_steps = 500000

def epsilon_greedy(action, step):
  p = np.random.random(1).squeeze() #1D entries returned using squeeze
  epsilon = max(eps_min, eps_max - (eps_max-eps_min) * step/eps_decay_steps) #Decaying policy with more steps
  if np.random.rand() < epsilon:
    return np.random.randint(n_outputs)
  else:
    return action

# %%
# Buffer

from collections import deque, Counter

buffer_len = 20000
#Buffer is made from a deque — double ended queue
exp_buffer = deque(maxlen=buffer_len)
def sample_memories(batch_size):
  perm_batch = np.random.permutation(len(exp_buffer))[:batch_size]
  mem = np.array(exp_buffer)[perm_batch]
  return mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]

# %%
# similarly we build our target Q network, for policy evaluation
targetQ, targetQ_outputs = q_network(X, 'targetQ')

X_action = tf.compat.v1.placeholder(tf.int32, shape=(None,))
Q_action = tf.reduce_sum(input_tensor=targetQ_outputs * tf.one_hot(X_action, n_outputs), axis=-1, keepdims=True)

# Copies target weights to main
copy_op = [tf.compat.v1.assign(main_name, targetQ[var_name]) for var_name, main_name in mainQ.items()]
copy_target_to_main = tf.group(*copy_op)

# %%
# Loss Function

# define a placeholder for our output i.e action
y = tf.compat.v1.placeholder(tf.float32, shape=(None,1))
# now we calculate the loss which is the difference between actual value and predicted value
loss = tf.reduce_mean(input_tensor=tf.square(y - Q_action))
# we use adam optimizer for minimizing the loss
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)
init = tf.compat.v1.global_variables_initializer()
loss_summary = tf.compat.v1.summary.scalar('LOSS', loss)
merge_summary = tf.compat.v1.summary.merge_all()
file_writer = tf.compat.v1.summary.FileWriter(logdir, tf.compat.v1.get_default_graph())

# %%
with tf.compat.v1.Session() as sess:
    init.run()
    
    # for each episode
    history = []
    for i in range(num_episodes):
        done = False
        obs = env.reset()
        epoch = 0
        episodic_reward = 0
        actions_counter = Counter() 
        episodic_loss = []

        # while the state is not the terminal state
        while not done:

           #env.render()
        
            # get the preprocessed game screen
            obs = preprocess_observation(obs)

            # feed the game screen and get the Q values for each action,  FEED THE NETWORK BY CALLING THE OUTPUT LAYER
            
            actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode:False})

            # get the action
            action = np.argmax(actions, axis=-1)
            actions_counter[str(action)] += 1 

            # select the action using epsilon greedy policy
            action = epsilon_greedy(action, global_step)
            
            # now perform the action and move to the next state, next_obs, receive reward
            next_obs, reward, done, _ = env.step(action)

            # Store this transistion as an experience in the replay buffer! Quite important
            exp_buffer.append([obs, action, preprocess_observation(next_obs), reward, done])
            
            # After certain steps, we train our Q network with samples from the experience replay buffer
            if global_step % steps_train == 0 and global_step > start_steps:
                
                # sample experience, mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]
                o_obs, o_act, o_next_obs, o_rew, o_done = sample_memories(batch_size)

                # states
                o_obs = [x for x in o_obs]

                # next states
                o_next_obs = [x for x in o_next_obs]

                # next actions
                next_act = mainQ_outputs.eval(feed_dict={X:o_next_obs, in_training_mode:False})


                # discounted reward: these are our Y-values
                y_batch = o_rew + discount_factor * np.max(next_act, axis=-1) * (1-o_done) 

                # merge all summaries and write to the file
                mrg_summary = merge_summary.eval(feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:False})
                file_writer.add_summary(mrg_summary, global_step)

                # To calculate the loss, we run the previously defined functions mentioned while feeding inputs
                train_loss, _ = sess.run([loss, training_op], feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:True})
                episodic_loss.append(train_loss)
            
            # after some interval we copy our main Q network weights to target Q network
            if (global_step+1) % copy_steps == 0 and global_step > start_steps:
                copy_target_to_main.run()
                
            obs = next_obs
            epoch += 1
            global_step += 1
            episodic_reward += reward
        
        history.append(episodic_reward)
        print('Epochs per episode:', epoch, 'Episode Reward:', episodic_reward,"Episode number:", len(history))

        # obj0, obj1, obj2 are created here...

        # Saving the objects:
        with open('/drive/MyDrive/RL_project/history.pkl', 'w') as f:  # Python 3: open(..., 'wb')
            pickle.dump(history, f)
# Out:
# Epochs per episode: 688 Episode Reward: 380.0 Episode number: 1
# Epochs per episode: 685 Episode Reward: 290.0 Episode number: 2
# Epochs per episode: 689 Episode Reward: 180.0 Episode number: 3
# Epochs per episode: 590 Episode Reward: 160.0 Episode number: 4
# Epochs per episode: 594 Episode Reward: 170.0 Episode number: 5
# Epochs per episode: 647 Episode Reward: 180.0 Episode number: 6
# Epochs per episode: 705 Episode Reward: 250.0 Episode number: 7
# Epochs per episode: 865 Episode Reward: 290.0 Episode number: 8
# Epochs per episode: 581 Episode Reward: 160.0 Episode number: 9
# Epochs per episode: 568 Episode Reward: 90.0 Episode number: 10
# Epochs per episode: 535 Episode Reward: 240.0 Episode number: 11
# Epochs per episode: 597 Episode Reward: 220.0 Episode number: 12
# Epochs per episode: 654 Episode Reward: 190.0 Episode number: 13
# Epochs per episode: 713 Episode Reward: 170.0 Episode number: 14
# Epochs per episode: 544 Episode Reward: 160.0 Episode number: 15
# Epochs per episode: 505 Episode Reward: 170.0 Episode number: 16
# Epochs per episode: 489 Episode Reward: 140.0 Episode number: 17
# Epochs per episode: 668 Episode Reward: 160.0 Episode number: 18
# Epochs per episode: 672 Episode Reward: 270.0 Episode number: 19
# Epochs per episode: 641 Episode Reward: 290.0 Episode number: 20
# Epochs per episode: 697 Episode Reward: 300.0 Episode number: 21
# Epochs per episode: 805 Episode Reward: 310.0 Episode number: 22
# Epochs per episode: 708 Episode Reward: 270.0 Episode number: 23
# Epochs per episode: 805 Episode Reward: 200.0 Episode number: 24
# Epochs per episode: 702 Episode Reward: 300.0 Episode number: 25
# Epochs per episode: 744 Episode Reward: 240.0 Episode number: 26
# Epochs per episode: 657 Episode Reward: 240.0 Episode number: 27
# Epochs per episode: 626 Episode Reward: 180.0 Episode number: 28
# Epochs per episode: 643 Episode Reward: 150.0 Episode number: 29
# Epochs per episode: 595 Episode Reward: 230.0 Episode number: 30
# Epochs per episode: 716 Episode Reward: 270.0 Episode number: 31
# Epochs per episode: 548 Episode Reward: 150.0 Episode number: 32
# Epochs per episode: 744 Episode Reward: 330.0 Episode number: 33
# Epochs per episode: 693 Episode Reward: 320.0 Episode number: 34
# Epochs per episode: 625 Episode Reward: 190.0 Episode number: 35
# Epochs per episode: 652 Episode Reward: 180.0 Episode number: 36
# Epochs per episode: 659 Episode Reward: 210.0 Episode number: 37
# Epochs per episode: 712 Episode Reward: 280.0 Episode number: 38
# Epochs per episode: 641 Episode Reward: 220.0 Episode number: 39
# Epochs per episode: 727 Episode Reward: 270.0 Episode number: 40
# Epochs per episode: 756 Episode Reward: 230.0 Episode number: 41
# Epochs per episode: 605 Episode Reward: 230.0 Episode number: 42
# Epochs per episode: 622 Episode Reward: 190.0 Episode number: 43
# Epochs per episode: 839 Episode Reward: 230.0 Episode number: 44
# Epochs per episode: 719 Episode Reward: 170.0 Episode number: 45
# Epochs per episode: 681 Episode Reward: 300.0 Episode number: 46
# Epochs per episode: 568 Episode Reward: 200.0 Episode number: 47
# Epochs per episode: 713 Episode Reward: 200.0 Episode number: 48
# Epochs per episode: 542 Episode Reward: 140.0 Episode number: 49
# Epochs per episode: 651 Episode Reward: 180.0 Episode number: 50
# Epochs per episode: 701 Episode Reward: 180.0 Episode number: 51
# Epochs per episode: 727 Episode Reward: 200.0 Episode number: 52
# Epochs per episode: 894 Episode Reward: 330.0 Episode number: 53
# Epochs per episode: 591 Episode Reward: 130.0 Episode number: 54
# Epochs per episode: 562 Episode Reward: 90.0 Episode number: 55
# Epochs per episode: 573 Episode Reward: 120.0 Episode number: 56
# Epochs per episode: 607 Episode Reward: 220.0 Episode number: 57
# Epochs per episode: 710 Episode Reward: 190.0 Episode number: 58
# Epochs per episode: 723 Episode Reward: 250.0 Episode number: 59
# Epochs per episode: 819 Episode Reward: 260.0 Episode number: 60
# Epochs per episode: 635 Episode Reward: 160.0 Episode number: 61
# Epochs per episode: 504 Episode Reward: 160.0 Episode number: 62
# Epochs per episode: 559 Episode Reward: 100.0 Episode number: 63
# Epochs per episode: 601 Episode Reward: 270.0 Episode number: 64
# Epochs per episode: 731 Episode Reward: 230.0 Episode number: 65
# Epochs per episode: 863 Episode Reward: 230.0 Episode number: 66
# Epochs per episode: 560 Episode Reward: 140.0 Episode number: 67
# Epochs per episode: 557 Episode Reward: 240.0 Episode number: 68
# Epochs per episode: 518 Episode Reward: 210.0 Episode number: 69
# Epochs per episode: 638 Episode Reward: 170.0 Episode number: 70
# Epochs per episode: 892 Episode Reward: 450.0 Episode number: 71
# Epochs per episode: 606 Episode Reward: 240.0 Episode number: 72
# Epochs per episode: 673 Episode Reward: 250.0 Episode number: 73
# Epochs per episode: 630 Episode Reward: 230.0 Episode number: 74
# Epochs per episode: 683 Episode Reward: 190.0 Episode number: 75
# Epochs per episode: 696 Episode Reward: 220.0 Episode number: 76
# Epochs per episode: 706 Episode Reward: 230.0 Episode number: 77
# Epochs per episode: 621 Episode Reward: 240.0 Episode number: 78
# Epochs per episode: 628 Episode Reward: 260.0 Episode number: 79
# Epochs per episode: 614 Episode Reward: 220.0 Episode number: 80
# Epochs per episode: 739 Episode Reward: 210.0 Episode number: 81
# Epochs per episode: 623 Episode Reward: 290.0 Episode number: 82
# Epochs per episode: 674 Episode Reward: 310.0 Episode number: 83
# Epochs per episode: 440 Episode Reward: 130.0 Episode number: 84
# Epochs per episode: 698 Episode Reward: 310.0 Episode number: 85
# Epochs per episode: 668 Episode Reward: 230.0 Episode number: 86
# Epochs per episode: 916 Episode Reward: 360.0 Episode number: 87
# Epochs per episode: 685 Episode Reward: 280.0 Episode number: 88
# Epochs per episode: 587 Episode Reward: 280.0 Episode number: 89
# Epochs per episode: 691 Episode Reward: 280.0 Episode number: 90
# Epochs per episode: 575 Episode Reward: 260.0 Episode number: 91
# Epochs per episode: 603 Episode Reward: 260.0 Episode number: 92
# Epochs per episode: 680 Episode Reward: 250.0 Episode number: 93
# Epochs per episode: 676 Episode Reward: 260.0 Episode number: 94
# Epochs per episode: 611 Episode Reward: 160.0 Episode number: 95
# Epochs per episode: 775 Episode Reward: 260.0 Episode number: 96
# Epochs per episode: 691 Episode Reward: 380.0 Episode number: 97
# Epochs per episode: 595 Episode Reward: 180.0 Episode number: 98
# Epochs per episode: 589 Episode Reward: 260.0 Episode number: 99
# Epochs per episode: 721 Episode Reward: 360.0 Episode number: 100
# Epochs per episode: 735 Episode Reward: 240.0 Episode number: 101
# Epochs per episode: 521 Episode Reward: 180.0 Episode number: 102
# Epochs per episode: 535 Episode Reward: 210.0 Episode number: 103
# Epochs per episode: 688 Episode Reward: 250.0 Episode number: 104
# Epochs per episode: 610 Episode Reward: 260.0 Episode number: 105
# Epochs per episode: 626 Episode Reward: 200.0 Episode number: 106
# Epochs per episode: 547 Episode Reward: 210.0 Episode number: 107
# Epochs per episode: 629 Episode Reward: 230.0 Episode number: 108
# Epochs per episode: 565 Episode Reward: 200.0 Episode number: 109
# Epochs per episode: 685 Episode Reward: 230.0 Episode number: 110
# Epochs per episode: 678 Episode Reward: 270.0 Episode number: 111
# Epochs per episode: 533 Episode Reward: 200.0 Episode number: 112
# Epochs per episode: 984 Episode Reward: 580.0 Episode number: 113
# Epochs per episode: 568 Episode Reward: 190.0 Episode number: 114
# Epochs per episode: 588 Episode Reward: 260.0 Episode number: 115
# Epochs per episode: 786 Episode Reward: 330.0 Episode number: 116
# Epochs per episode: 685 Episode Reward: 390.0 Episode number: 117
# Epochs per episode: 570 Episode Reward: 240.0 Episode number: 118
# Epochs per episode: 816 Episode Reward: 230.0 Episode number: 119
# Epochs per episode: 730 Episode Reward: 320.0 Episode number: 120
# Epochs per episode: 606 Episode Reward: 230.0 Episode number: 121
# Epochs per episode: 524 Episode Reward: 120.0 Episode number: 122
# Epochs per episode: 699 Episode Reward: 280.0 Episode number: 123
# Epochs per episode: 671 Episode Reward: 200.0 Episode number: 124
# Epochs per episode: 606 Episode Reward: 240.0 Episode number: 125
# Epochs per episode: 732 Episode Reward: 240.0 Episode number: 126
# Epochs per episode: 654 Episode Reward: 300.0 Episode number: 127
# Epochs per episode: 705 Episode Reward: 340.0 Episode number: 128
# Epochs per episode: 911 Episode Reward: 630.0 Episode number: 129
# Epochs per episode: 675 Episode Reward: 240.0 Episode number: 130
# Epochs per episode: 658 Episode Reward: 190.0 Episode number: 131
# Epochs per episode: 709 Episode Reward: 300.0 Episode number: 132
# Epochs per episode: 741 Episode Reward: 240.0 Episode number: 133
# Epochs per episode: 656 Episode Reward: 250.0 Episode number: 134
# Epochs per episode: 1012 Episode Reward: 680.0 Episode number: 135
# Epochs per episode: 602 Episode Reward: 170.0 Episode number: 136
# Epochs per episode: 545 Episode Reward: 160.0 Episode number: 137
# Epochs per episode: 956 Episode Reward: 440.0 Episode number: 138
# Epochs per episode: 593 Episode Reward: 220.0 Episode number: 139
# Epochs per episode: 606 Episode Reward: 180.0 Episode number: 140
# Epochs per episode: 544 Episode Reward: 200.0 Episode number: 141
# Epochs per episode: 669 Episode Reward: 290.0 Episode number: 142
# Epochs per episode: 499 Episode Reward: 210.0 Episode number: 143
# Epochs per episode: 545 Episode Reward: 210.0 Episode number: 144
# Epochs per episode: 701 Episode Reward: 230.0 Episode number: 145
# Epochs per episode: 678 Episode Reward: 170.0 Episode number: 146
# Epochs per episode: 633 Episode Reward: 200.0 Episode number: 147
# Epochs per episode: 741 Episode Reward: 260.0 Episode number: 148
# Epochs per episode: 598 Episode Reward: 240.0 Episode number: 149
# Epochs per episode: 917 Episode Reward: 500.0 Episode number: 150
# Epochs per episode: 682 Episode Reward: 240.0 Episode number: 151
# Epochs per episode: 674 Episode Reward: 250.0 Episode number: 152
# Epochs per episode: 479 Episode Reward: 180.0 Episode number: 153
# Epochs per episode: 660 Episode Reward: 240.0 Episode number: 154
# Epochs per episode: 639 Episode Reward: 350.0 Episode number: 155
# Epochs per episode: 594 Episode Reward: 260.0 Episode number: 156
# Epochs per episode: 613 Episode Reward: 280.0 Episode number: 157
# Epochs per episode: 729 Episode Reward: 300.0 Episode number: 158
# Epochs per episode: 649 Episode Reward: 200.0 Episode number: 159
# Epochs per episode: 926 Episode Reward: 630.0 Episode number: 160
# Epochs per episode: 607 Episode Reward: 160.0 Episode number: 161
# Epochs per episode: 785 Episode Reward: 290.0 Episode number: 162
# Epochs per episode: 579 Episode Reward: 260.0 Episode number: 163
# Epochs per episode: 595 Episode Reward: 170.0 Episode number: 164
# Epochs per episode: 611 Episode Reward: 200.0 Episode number: 165
# Epochs per episode: 1113 Episode Reward: 1460.0 Episode number: 166
# Epochs per episode: 825 Episode Reward: 230.0 Episode number: 167
# Epochs per episode: 989 Episode Reward: 650.0 Episode number: 168
# Epochs per episode: 736 Episode Reward: 260.0 Episode number: 169
# Epochs per episode: 704 Episode Reward: 280.0 Episode number: 170
# Epochs per episode: 480 Episode Reward: 210.0 Episode number: 171
# Epochs per episode: 625 Episode Reward: 290.0 Episode number: 172
# Epochs per episode: 532 Episode Reward: 230.0 Episode number: 173
# Epochs per episode: 503 Episode Reward: 220.0 Episode number: 174
# Epochs per episode: 894 Episode Reward: 350.0 Episode number: 175
# Epochs per episode: 766 Episode Reward: 430.0 Episode number: 176
# Epochs per episode: 538 Episode Reward: 180.0 Episode number: 177
# Epochs per episode: 622 Episode Reward: 270.0 Episode number: 178
# Epochs per episode: 523 Episode Reward: 170.0 Episode number: 179
# Epochs per episode: 852 Episode Reward: 410.0 Episode number: 180
# Epochs per episode: 564 Episode Reward: 220.0 Episode number: 181
# Epochs per episode: 444 Episode Reward: 140.0 Episode number: 182
# Epochs per episode: 604 Episode Reward: 220.0 Episode number: 183
# Epochs per episode: 546 Episode Reward: 160.0 Episode number: 184
# Epochs per episode: 564 Episode Reward: 240.0 Episode number: 185
# Epochs per episode: 511 Episode Reward: 150.0 Episode number: 186
# Epochs per episode: 724 Episode Reward: 440.0 Episode number: 187
# Epochs per episode: 650 Episode Reward: 320.0 Episode number: 188
# Epochs per episode: 714 Episode Reward: 230.0 Episode number: 189
# Epochs per episode: 680 Episode Reward: 270.0 Episode number: 190
# Epochs per episode: 592 Episode Reward: 310.0 Episode number: 191
# Epochs per episode: 716 Episode Reward: 350.0 Episode number: 192
# Epochs per episode: 631 Episode Reward: 180.0 Episode number: 193
# Epochs per episode: 663 Episode Reward: 230.0 Episode number: 194
# Epochs per episode: 846 Episode Reward: 670.0 Episode number: 195
# Epochs per episode: 499 Episode Reward: 210.0 Episode number: 196
# Epochs per episode: 703 Episode Reward: 350.0 Episode number: 197
# Epochs per episode: 735 Episode Reward: 250.0 Episode number: 198
# Epochs per episode: 612 Episode Reward: 260.0 Episode number: 199
# Epochs per episode: 596 Episode Reward: 220.0 Episode number: 200
# Epochs per episode: 685 Episode Reward: 210.0 Episode number: 201
# Epochs per episode: 826 Episode Reward: 630.0 Episode number: 202
# Epochs per episode: 867 Episode Reward: 570.0 Episode number: 203
# Epochs per episode: 687 Episode Reward: 300.0 Episode number: 204
# Epochs per episode: 751 Episode Reward: 650.0 Episode number: 205
# Epochs per episode: 636 Episode Reward: 220.0 Episode number: 206
# Epochs per episode: 539 Episode Reward: 200.0 Episode number: 207
# Epochs per episode: 570 Episode Reward: 250.0 Episode number: 208
# Epochs per episode: 637 Episode Reward: 290.0 Episode number: 209
# Epochs per episode: 522 Episode Reward: 210.0 Episode number: 210
# Epochs per episode: 525 Episode Reward: 220.0 Episode number: 211
# Epochs per episode: 669 Episode Reward: 380.0 Episode number: 212
# Epochs per episode: 527 Episode Reward: 240.0 Episode number: 213
# Epochs per episode: 582 Episode Reward: 190.0 Episode number: 214
# Epochs per episode: 703 Episode Reward: 320.0 Episode number: 215
# Epochs per episode: 636 Episode Reward: 150.0 Episode number: 216
# Epochs per episode: 620 Episode Reward: 300.0 Episode number: 217
# Epochs per episode: 681 Episode Reward: 290.0 Episode number: 218
# Epochs per episode: 885 Episode Reward: 1110.0 Episode number: 219
# Epochs per episode: 873 Episode Reward: 760.0 Episode number: 220
# Epochs per episode: 591 Episode Reward: 230.0 Episode number: 221
# Epochs per episode: 541 Episode Reward: 270.0 Episode number: 222
# Epochs per episode: 686 Episode Reward: 160.0 Episode number: 223
# Epochs per episode: 656 Episode Reward: 190.0 Episode number: 224
# Epochs per episode: 879 Episode Reward: 670.0 Episode number: 225
# Epochs per episode: 565 Episode Reward: 190.0 Episode number: 226
# Epochs per episode: 661 Episode Reward: 310.0 Episode number: 227
# Epochs per episode: 788 Episode Reward: 580.0 Episode number: 228
# Epochs per episode: 775 Episode Reward: 260.0 Episode number: 229
# Epochs per episode: 851 Episode Reward: 620.0 Episode number: 230
# Epochs per episode: 580 Episode Reward: 260.0 Episode number: 231
# Epochs per episode: 1030 Episode Reward: 380.0 Episode number: 232
# Epochs per episode: 491 Episode Reward: 220.0 Episode number: 233
# Epochs per episode: 1158 Episode Reward: 860.0 Episode number: 234
# Epochs per episode: 570 Episode Reward: 210.0 Episode number: 235
# Epochs per episode: 901 Episode Reward: 680.0 Episode number: 236
# Epochs per episode: 608 Episode Reward: 280.0 Episode number: 237
# Epochs per episode: 919 Episode Reward: 580.0 Episode number: 238
# Epochs per episode: 1076 Episode Reward: 500.0 Episode number: 239
# Epochs per episode: 639 Episode Reward: 200.0 Episode number: 240
# Epochs per episode: 646 Episode Reward: 290.0 Episode number: 241
# Epochs per episode: 578 Episode Reward: 220.0 Episode number: 242
# Epochs per episode: 641 Episode Reward: 350.0 Episode number: 243
# Epochs per episode: 983 Episode Reward: 540.0 Episode number: 244
# Epochs per episode: 693 Episode Reward: 270.0 Episode number: 245
# Epochs per episode: 715 Episode Reward: 380.0 Episode number: 246
# Epochs per episode: 524 Episode Reward: 180.0 Episode number: 247
# Epochs per episode: 677 Episode Reward: 340.0 Episode number: 248
# Epochs per episode: 604 Episode Reward: 260.0 Episode number: 249
# Epochs per episode: 886 Episode Reward: 290.0 Episode number: 250
# Epochs per episode: 837 Episode Reward: 940.0 Episode number: 251
# Epochs per episode: 720 Episode Reward: 210.0 Episode number: 252
# Epochs per episode: 565 Episode Reward: 200.0 Episode number: 253
# Epochs per episode: 1186 Episode Reward: 360.0 Episode number: 254
# Epochs per episode: 736 Episode Reward: 350.0 Episode number: 255
# Epochs per episode: 520 Episode Reward: 220.0 Episode number: 256
# Epochs per episode: 436 Episode Reward: 140.0 Episode number: 257
# Epochs per episode: 685 Episode Reward: 290.0 Episode number: 258
# Epochs per episode: 911 Episode Reward: 1000.0 Episode number: 259
# Epochs per episode: 580 Episode Reward: 280.0 Episode number: 260
# Epochs per episode: 996 Episode Reward: 580.0 Episode number: 261
# Epochs per episode: 577 Episode Reward: 190.0 Episode number: 262
# Epochs per episode: 587 Episode Reward: 280.0 Episode number: 263
# Epochs per episode: 625 Episode Reward: 360.0 Episode number: 264
# Epochs per episode: 660 Episode Reward: 280.0 Episode number: 265
# Epochs per episode: 844 Episode Reward: 410.0 Episode number: 266
# Epochs per episode: 633 Episode Reward: 250.0 Episode number: 267
# Epochs per episode: 674 Episode Reward: 280.0 Episode number: 268
# Epochs per episode: 817 Episode Reward: 700.0 Episode number: 269
# Epochs per episode: 580 Episode Reward: 240.0 Episode number: 270
# Epochs per episode: 601 Episode Reward: 210.0 Episode number: 271
# Epochs per episode: 630 Episode Reward: 180.0 Episode number: 272
# Epochs per episode: 723 Episode Reward: 210.0 Episode number: 273
# Epochs per episode: 843 Episode Reward: 430.0 Episode number: 274
# Epochs per episode: 676 Episode Reward: 320.0 Episode number: 275
# Epochs per episode: 780 Episode Reward: 710.0 Episode number: 276
# Epochs per episode: 654 Episode Reward: 250.0 Episode number: 277
# Epochs per episode: 733 Episode Reward: 400.0 Episode number: 278
# Epochs per episode: 578 Episode Reward: 390.0 Episode number: 279
# Epochs per episode: 787 Episode Reward: 510.0 Episode number: 280
# Epochs per episode: 651 Episode Reward: 370.0 Episode number: 281
# Epochs per episode: 615 Episode Reward: 310.0 Episode number: 282
# Epochs per episode: 584 Episode Reward: 260.0 Episode number: 283
# Epochs per episode: 1349 Episode Reward: 1430.0 Episode number: 284
# Epochs per episode: 788 Episode Reward: 380.0 Episode number: 285
# Epochs per episode: 870 Episode Reward: 530.0 Episode number: 286
# Epochs per episode: 632 Episode Reward: 260.0 Episode number: 287
# Epochs per episode: 584 Episode Reward: 340.0 Episode number: 288
# Epochs per episode: 651 Episode Reward: 200.0 Episode number: 289
# Epochs per episode: 565 Episode Reward: 300.0 Episode number: 290
# Epochs per episode: 551 Episode Reward: 220.0 Episode number: 291
# Epochs per episode: 641 Episode Reward: 270.0 Episode number: 292
# Epochs per episode: 528 Episode Reward: 280.0 Episode number: 293
# Epochs per episode: 444 Episode Reward: 140.0 Episode number: 294
# Epochs per episode: 621 Episode Reward: 290.0 Episode number: 295
# Epochs per episode: 765 Episode Reward: 470.0 Episode number: 296
# Epochs per episode: 827 Episode Reward: 590.0 Episode number: 297
# Epochs per episode: 470 Episode Reward: 190.0 Episode number: 298
# Epochs per episode: 614 Episode Reward: 220.0 Episode number: 299
# Epochs per episode: 815 Episode Reward: 520.0 Episode number: 300
# Epochs per episode: 747 Episode Reward: 310.0 Episode number: 301
# Epochs per episode: 634 Episode Reward: 320.0 Episode number: 302
# Epochs per episode: 1042 Episode Reward: 1530.0 Episode number: 303
# Epochs per episode: 570 Episode Reward: 230.0 Episode number: 304
# Epochs per episode: 874 Episode Reward: 500.0 Episode number: 305
# Epochs per episode: 875 Episode Reward: 500.0 Episode number: 306
# Epochs per episode: 761 Episode Reward: 430.0 Episode number: 307
# Epochs per episode: 634 Episode Reward: 290.0 Episode number: 308
# Epochs per episode: 481 Episode Reward: 200.0 Episode number: 309
# Epochs per episode: 574 Episode Reward: 250.0 Episode number: 310
# Epochs per episode: 604 Episode Reward: 250.0 Episode number: 311
# Epochs per episode: 486 Episode Reward: 310.0 Episode number: 312
# Epochs per episode: 449 Episode Reward: 230.0 Episode number: 313
# Epochs per episode: 686 Episode Reward: 250.0 Episode number: 314
# Epochs per episode: 1003 Episode Reward: 480.0 Episode number: 315
# Epochs per episode: 536 Episode Reward: 270.0 Episode number: 316
# Epochs per episode: 542 Episode Reward: 290.0 Episode number: 317
# Epochs per episode: 480 Episode Reward: 190.0 Episode number: 318
# Epochs per episode: 578 Episode Reward: 290.0 Episode number: 319
# Epochs per episode: 608 Episode Reward: 220.0 Episode number: 320
# Epochs per episode: 1229 Episode Reward: 1100.0 Episode number: 321
# Epochs per episode: 697 Episode Reward: 320.0 Episode number: 322
# Epochs per episode: 892 Episode Reward: 420.0 Episode number: 323
# Epochs per episode: 662 Episode Reward: 390.0 Episode number: 324
# Epochs per episode: 862 Episode Reward: 460.0 Episode number: 325
# Epochs per episode: 610 Episode Reward: 280.0 Episode number: 326
# Epochs per episode: 949 Episode Reward: 530.0 Episode number: 327
# Epochs per episode: 590 Episode Reward: 200.0 Episode number: 328
# Epochs per episode: 580 Episode Reward: 250.0 Episode number: 329
# Epochs per episode: 662 Episode Reward: 260.0 Episode number: 330
# Epochs per episode: 1168 Episode Reward: 1260.0 Episode number: 331
# Epochs per episode: 703 Episode Reward: 470.0 Episode number: 332
# Epochs per episode: 600 Episode Reward: 250.0 Episode number: 333
# Epochs per episode: 717 Episode Reward: 400.0 Episode number: 334
# Epochs per episode: 639 Episode Reward: 380.0 Episode number: 335
# Epochs per episode: 622 Episode Reward: 280.0 Episode number: 336
# Epochs per episode: 460 Episode Reward: 190.0 Episode number: 337
# Epochs per episode: 1069 Episode Reward: 650.0 Episode number: 338
# Epochs per episode: 1216 Episode Reward: 530.0 Episode number: 339
# Epochs per episode: 684 Episode Reward: 390.0 Episode number: 340
# Epochs per episode: 604 Episode Reward: 350.0 Episode number: 341
# Epochs per episode: 608 Episode Reward: 360.0 Episode number: 342
# Epochs per episode: 1451 Episode Reward: 1790.0 Episode number: 343
# Epochs per episode: 923 Episode Reward: 600.0 Episode number: 344
# Epochs per episode: 897 Episode Reward: 810.0 Episode number: 345
# Epochs per episode: 995 Episode Reward: 1880.0 Episode number: 346
# Epochs per episode: 775 Episode Reward: 280.0 Episode number: 347
# Epochs per episode: 653 Episode Reward: 480.0 Episode number: 348
# Epochs per episode: 879 Episode Reward: 490.0 Episode number: 349
# Epochs per episode: 530 Episode Reward: 250.0 Episode number: 350
# Epochs per episode: 665 Episode Reward: 500.0 Episode number: 351
# Epochs per episode: 548 Episode Reward: 160.0 Episode number: 352
# Epochs per episode: 871 Episode Reward: 730.0 Episode number: 353
# Epochs per episode: 631 Episode Reward: 410.0 Episode number: 354
# Epochs per episode: 663 Episode Reward: 240.0 Episode number: 355
# Epochs per episode: 550 Episode Reward: 280.0 Episode number: 356
# Epochs per episode: 598 Episode Reward: 330.0 Episode number: 357
# Epochs per episode: 1363 Episode Reward: 1170.0 Episode number: 358
# Epochs per episode: 639 Episode Reward: 380.0 Episode number: 359
# Epochs per episode: 458 Episode Reward: 210.0 Episode number: 360
# Epochs per episode: 639 Episode Reward: 490.0 Episode number: 361
# Epochs per episode: 552 Episode Reward: 140.0 Episode number: 362
# Epochs per episode: 1098 Episode Reward: 620.0 Episode number: 363
# Epochs per episode: 794 Episode Reward: 660.0 Episode number: 364
# Epochs per episode: 764 Episode Reward: 640.0 Episode number: 365
# Epochs per episode: 842 Episode Reward: 580.0 Episode number: 366
# Epochs per episode: 887 Episode Reward: 1900.0 Episode number: 367
# Epochs per episode: 737 Episode Reward: 590.0 Episode number: 368
# Epochs per episode: 506 Episode Reward: 300.0 Episode number: 369
# Epochs per episode: 905 Episode Reward: 1040.0 Episode number: 370
# Epochs per episode: 1246 Episode Reward: 1530.0 Episode number: 371
# Epochs per episode: 741 Episode Reward: 410.0 Episode number: 372
# Epochs per episode: 1135 Episode Reward: 460.0 Episode number: 373
# Epochs per episode: 585 Episode Reward: 150.0 Episode number: 374
# Epochs per episode: 612 Episode Reward: 250.0 Episode number: 375
# Epochs per episode: 625 Episode Reward: 290.0 Episode number: 376
# Epochs per episode: 821 Episode Reward: 470.0 Episode number: 377
# Epochs per episode: 508 Episode Reward: 280.0 Episode number: 378
# Epochs per episode: 1097 Episode Reward: 660.0 Episode number: 379
# Epochs per episode: 804 Episode Reward: 1160.0 Episode number: 380
# Epochs per episode: 557 Episode Reward: 340.0 Episode number: 381
# Epochs per episode: 678 Episode Reward: 350.0 Episode number: 382
# Epochs per episode: 1037 Episode Reward: 500.0 Episode number: 383
# Epochs per episode: 704 Episode Reward: 980.0 Episode number: 384
# Epochs per episode: 682 Episode Reward: 430.0 Episode number: 385
# Epochs per episode: 773 Episode Reward: 440.0 Episode number: 386
# Epochs per episode: 884 Episode Reward: 480.0 Episode number: 387
# Epochs per episode: 606 Episode Reward: 370.0 Episode number: 388
# Epochs per episode: 624 Episode Reward: 240.0 Episode number: 389
# Epochs per episode: 853 Episode Reward: 620.0 Episode number: 390
# Epochs per episode: 532 Episode Reward: 270.0 Episode number: 391
# Epochs per episode: 989 Episode Reward: 700.0 Episode number: 392
# Epochs per episode: 887 Episode Reward: 640.0 Episode number: 393
# Epochs per episode: 817 Episode Reward: 490.0 Episode number: 394
# Epochs per episode: 788 Episode Reward: 720.0 Episode number: 395
# Epochs per episode: 1644 Episode Reward: 860.0 Episode number: 396
# Epochs per episode: 653 Episode Reward: 500.0 Episode number: 397
# Epochs per episode: 798 Episode Reward: 670.0 Episode number: 398
# Epochs per episode: 643 Episode Reward: 350.0 Episode number: 399
# Epochs per episode: 602 Episode Reward: 290.0 Episode number: 400
# Epochs per episode: 903 Episode Reward: 570.0 Episode number: 401
# Epochs per episode: 915 Episode Reward: 410.0 Episode number: 402
# Epochs per episode: 525 Episode Reward: 240.0 Episode number: 403
# Epochs per episode: 896 Episode Reward: 760.0 Episode number: 404
# Epochs per episode: 524 Episode Reward: 240.0 Episode number: 405
# Epochs per episode: 575 Episode Reward: 320.0 Episode number: 406
# Epochs per episode: 675 Episode Reward: 350.0 Episode number: 407
# Epochs per episode: 827 Episode Reward: 790.0 Episode number: 408
# Epochs per episode: 784 Episode Reward: 670.0 Episode number: 409
# Epochs per episode: 743 Episode Reward: 370.0 Episode number: 410
# Epochs per episode: 688 Episode Reward: 600.0 Episode number: 411
# Epochs per episode: 982 Episode Reward: 310.0 Episode number: 412
# Epochs per episode: 862 Episode Reward: 600.0 Episode number: 413
# Epochs per episode: 873 Episode Reward: 1880.0 Episode number: 414
# Epochs per episode: 840 Episode Reward: 420.0 Episode number: 415
# Epochs per episode: 860 Episode Reward: 420.0 Episode number: 416
# Epochs per episode: 734 Episode Reward: 450.0 Episode number: 417
# Epochs per episode: 880 Episode Reward: 600.0 Episode number: 418
# Epochs per episode: 660 Episode Reward: 460.0 Episode number: 419
# Epochs per episode: 812 Episode Reward: 530.0 Episode number: 420
# Epochs per episode: 750 Episode Reward: 970.0 Episode number: 421
# Epochs per episode: 653 Episode Reward: 330.0 Episode number: 422
# Epochs per episode: 699 Episode Reward: 290.0 Episode number: 423
# Epochs per episode: 611 Episode Reward: 840.0 Episode number: 424
# Epochs per episode: 1100 Episode Reward: 1520.0 Episode number: 425
# Epochs per episode: 816 Episode Reward: 560.0 Episode number: 426
# Epochs per episode: 811 Episode Reward: 440.0 Episode number: 427
# Epochs per episode: 826 Episode Reward: 1080.0 Episode number: 428
# Epochs per episode: 577 Episode Reward: 300.0 Episode number: 429
# Epochs per episode: 539 Episode Reward: 280.0 Episode number: 430
# Epochs per episode: 536 Episode Reward: 370.0 Episode number: 431
# Epochs per episode: 744 Episode Reward: 720.0 Episode number: 432
# Epochs per episode: 895 Episode Reward: 590.0 Episode number: 433
# Epochs per episode: 767 Episode Reward: 720.0 Episode number: 434
# Epochs per episode: 819 Episode Reward: 510.0 Episode number: 435
# Epochs per episode: 1181 Episode Reward: 1120.0 Episode number: 436
# Epochs per episode: 884 Episode Reward: 640.0 Episode number: 437
# Epochs per episode: 431 Episode Reward: 260.0 Episode number: 438
# Epochs per episode: 724 Episode Reward: 670.0 Episode number: 439
# Epochs per episode: 976 Episode Reward: 770.0 Episode number: 440
# Epochs per episode: 704 Episode Reward: 340.0 Episode number: 441
# Epochs per episode: 520 Episode Reward: 180.0 Episode number: 442
# Epochs per episode: 1017 Episode Reward: 740.0 Episode number: 443
# Epochs per episode: 539 Episode Reward: 340.0 Episode number: 444
# Epochs per episode: 706 Episode Reward: 320.0 Episode number: 445
# Epochs per episode: 493 Episode Reward: 130.0 Episode number: 446
# Epochs per episode: 680 Episode Reward: 360.0 Episode number: 447
# Epochs per episode: 722 Episode Reward: 610.0 Episode number: 448
# Epochs per episode: 951 Episode Reward: 850.0 Episode number: 449
# Epochs per episode: 1828 Episode Reward: 980.0 Episode number: 450
# Epochs per episode: 454 Episode Reward: 170.0 Episode number: 451
# Epochs per episode: 807 Episode Reward: 610.0 Episode number: 452
# Epochs per episode: 974 Episode Reward: 520.0 Episode number: 453
# Epochs per episode: 824 Episode Reward: 740.0 Episode number: 454
# Epochs per episode: 560 Episode Reward: 230.0 Episode number: 455
# Epochs per episode: 743 Episode Reward: 410.0 Episode number: 456
# Epochs per episode: 703 Episode Reward: 450.0 Episode number: 457
# Epochs per episode: 830 Episode Reward: 1970.0 Episode number: 458
# Epochs per episode: 774 Episode Reward: 420.0 Episode number: 459
# Epochs per episode: 962 Episode Reward: 540.0 Episode number: 460
# Epochs per episode: 1037 Episode Reward: 560.0 Episode number: 461
# Epochs per episode: 677 Episode Reward: 380.0 Episode number: 462
# Epochs per episode: 439 Episode Reward: 250.0 Episode number: 463
# Epochs per episode: 538 Episode Reward: 270.0 Episode number: 464
# Epochs per episode: 957 Episode Reward: 440.0 Episode number: 465
# Epochs per episode: 942 Episode Reward: 1030.0 Episode number: 466
# Epochs per episode: 1487 Episode Reward: 580.0 Episode number: 467
# Epochs per episode: 848 Episode Reward: 620.0 Episode number: 468
# Epochs per episode: 1012 Episode Reward: 730.0 Episode number: 469
# Epochs per episode: 1030 Episode Reward: 640.0 Episode number: 470
# Epochs per episode: 735 Episode Reward: 460.0 Episode number: 471
# Epochs per episode: 830 Episode Reward: 460.0 Episode number: 472
# Epochs per episode: 900 Episode Reward: 610.0 Episode number: 473
# Epochs per episode: 673 Episode Reward: 370.0 Episode number: 474
# Epochs per episode: 657 Episode Reward: 280.0 Episode number: 475
# Epochs per episode: 709 Episode Reward: 420.0 Episode number: 476
# Epochs per episode: 925 Episode Reward: 490.0 Episode number: 477
# Epochs per episode: 1056 Episode Reward: 770.0 Episode number: 478
# Epochs per episode: 586 Episode Reward: 400.0 Episode number: 479
# Epochs per episode: 895 Episode Reward: 360.0 Episode number: 480
# Epochs per episode: 1151 Episode Reward: 980.0 Episode number: 481
# Epochs per episode: 652 Episode Reward: 470.0 Episode number: 482
# Epochs per episode: 528 Episode Reward: 240.0 Episode number: 483
# Epochs per episode: 816 Episode Reward: 560.0 Episode number: 484
# Epochs per episode: 584 Episode Reward: 290.0 Episode number: 485
# Epochs per episode: 544 Episode Reward: 160.0 Episode number: 486
# Epochs per episode: 678 Episode Reward: 330.0 Episode number: 487
# Epochs per episode: 892 Episode Reward: 2010.0 Episode number: 488
# Epochs per episode: 740 Episode Reward: 520.0 Episode number: 489
# Epochs per episode: 859 Episode Reward: 730.0 Episode number: 490
# Epochs per episode: 1216 Episode Reward: 1280.0 Episode number: 491
# Epochs per episode: 1045 Episode Reward: 1110.0 Episode number: 492
# Epochs per episode: 1094 Episode Reward: 1390.0 Episode number: 493
# Epochs per episode: 454 Episode Reward: 160.0 Episode number: 494
# Epochs per episode: 623 Episode Reward: 380.0 Episode number: 495
# Epochs per episode: 830 Episode Reward: 840.0 Episode number: 496
# Epochs per episode: 844 Episode Reward: 780.0 Episode number: 497
# Epochs per episode: 592 Episode Reward: 340.0 Episode number: 498
# Epochs per episode: 869 Episode Reward: 390.0 Episode number: 499
# Epochs per episode: 529 Episode Reward: 220.0 Episode number: 500
# Epochs per episode: 631 Episode Reward: 550.0 Episode number: 501
# Epochs per episode: 820 Episode Reward: 670.0 Episode number: 502
# Epochs per episode: 993 Episode Reward: 810.0 Episode number: 503
# Epochs per episode: 748 Episode Reward: 480.0 Episode number: 504
# Epochs per episode: 1362 Episode Reward: 680.0 Episode number: 505
# Epochs per episode: 698 Episode Reward: 350.0 Episode number: 506
# Epochs per episode: 826 Episode Reward: 760.0 Episode number: 507
# Epochs per episode: 493 Episode Reward: 280.0 Episode number: 508
# Epochs per episode: 1042 Episode Reward: 930.0 Episode number: 509
# Epochs per episode: 831 Episode Reward: 660.0 Episode number: 510
# Epochs per episode: 583 Episode Reward: 420.0 Episode number: 511
# Epochs per episode: 568 Episode Reward: 460.0 Episode number: 512
# Epochs per episode: 869 Episode Reward: 840.0 Episode number: 513
# Epochs per episode: 584 Episode Reward: 410.0 Episode number: 514
# Epochs per episode: 823 Episode Reward: 470.0 Episode number: 515
# Epochs per episode: 844 Episode Reward: 590.0 Episode number: 516
# Epochs per episode: 531 Episode Reward: 340.0 Episode number: 517
# Epochs per episode: 926 Episode Reward: 1180.0 Episode number: 518
# Epochs per episode: 644 Episode Reward: 540.0 Episode number: 519
# Epochs per episode: 1253 Episode Reward: 1570.0 Episode number: 520
# Epochs per episode: 817 Episode Reward: 470.0 Episode number: 521
# Epochs per episode: 853 Episode Reward: 570.0 Episode number: 522
# Epochs per episode: 933 Episode Reward: 410.0 Episode number: 523
# Epochs per episode: 640 Episode Reward: 500.0 Episode number: 524
# Epochs per episode: 713 Episode Reward: 290.0 Episode number: 525
# Epochs per episode: 524 Episode Reward: 330.0 Episode number: 526
# Epochs per episode: 514 Episode Reward: 190.0 Episode number: 527
# Epochs per episode: 726 Episode Reward: 510.0 Episode number: 528
# Epochs per episode: 547 Episode Reward: 280.0 Episode number: 529
# Epochs per episode: 554 Episode Reward: 340.0 Episode number: 530
# Epochs per episode: 716 Episode Reward: 480.0 Episode number: 531
# Epochs per episode: 858 Episode Reward: 600.0 Episode number: 532
# Epochs per episode: 917 Episode Reward: 680.0 Episode number: 533
# Epochs per episode: 605 Episode Reward: 410.0 Episode number: 534
# Epochs per episode: 757 Episode Reward: 440.0 Episode number: 535
# Epochs per episode: 1130 Episode Reward: 1040.0 Episode number: 536
# Epochs per episode: 738 Episode Reward: 520.0 Episode number: 537
# Epochs per episode: 823 Episode Reward: 450.0 Episode number: 538
# Epochs per episode: 577 Episode Reward: 420.0 Episode number: 539
# Epochs per episode: 423 Episode Reward: 270.0 Episode number: 540
# Epochs per episode: 516 Episode Reward: 260.0 Episode number: 541
# Epochs per episode: 543 Episode Reward: 380.0 Episode number: 542
# Epochs per episode: 1032 Episode Reward: 600.0 Episode number: 543
# Epochs per episode: 528 Episode Reward: 410.0 Episode number: 544
# Epochs per episode: 906 Episode Reward: 720.0 Episode number: 545
# Epochs per episode: 584 Episode Reward: 400.0 Episode number: 546
# Epochs per episode: 837 Episode Reward: 800.0 Episode number: 547
# Epochs per episode: 931 Episode Reward: 1170.0 Episode number: 548
# Epochs per episode: 616 Episode Reward: 310.0 Episode number: 549
# Epochs per episode: 676 Episode Reward: 700.0 Episode number: 550
# Epochs per episode: 1097 Episode Reward: 950.0 Episode number: 551
# Epochs per episode: 1095 Episode Reward: 760.0 Episode number: 552
# Epochs per episode: 646 Episode Reward: 440.0 Episode number: 553
# Epochs per episode: 849 Episode Reward: 790.0 Episode number: 554
# Epochs per episode: 1189 Episode Reward: 1280.0 Episode number: 555
# Epochs per episode: 691 Episode Reward: 490.0 Episode number: 556
# Epochs per episode: 698 Episode Reward: 340.0 Episode number: 557
# Epochs per episode: 923 Episode Reward: 770.0 Episode number: 558
# Epochs per episode: 980 Episode Reward: 1080.0 Episode number: 559
# Epochs per episode: 799 Episode Reward: 470.0 Episode number: 560
# Epochs per episode: 1024 Episode Reward: 830.0 Episode number: 561
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-118-a0605c96b444> in <module>()
#      41
#      42                 # sample experience, mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]
# ---> 43                 o_obs, o_act, o_next_obs, o_rew, o_done = sample_memories(batch_size)
#      44
#      45                 # states
#
# <ipython-input-88-b2c6714babec> in sample_memories(batch_size)
#       8 def sample_memories(batch_size):
#       9   perm_batch = np.random.permutation(len(exp_buffer))[:batch_size]
# ---> 10   mem = np.array(exp_buffer)[perm_batch]
#      11   return mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]
#
# KeyboardInterrupt:

# %%
plt.plot(history)
plt.show()

# %%
# Saving the objects:
data_to_save = ['history', 'mainQ']
data_location = './drive/MyDrive/data.pkl'
def save_variables():
  try:
    with open(data_location, 'wb') as f:  # Python 3: open(..., 'wb')
      for var in data_to_save:
        eval(f"pickle.dump({var}, f)")
    print(f"History saved to {data_location}")
  except FileNotFoundError:
    print("Mount google drive if you wish to save the history")

def load_variables():
  # Getting back the objects:
  with open(data_location, 'rb') as f:  # Python 3: open(..., 'rb')
      for var in data_to_save:
        exec(f"{var} = pickle.load(f)")
  return history
# Out:
# History saved to './drive/MyDrive/history.pkl'

# %%
# Copy of above, wihh episode variable nearer
num_episodes = 10

with tf.compat.v1.Session() as sess:
    init.run()
    
    # for each episode
    history = []
    for i in range(num_episodes):
        done = False
        obs = env.reset()
        epoch = 0
        episodic_reward = 0
        actions_counter = Counter() 
        episodic_loss = []

        # while the state is not the terminal state
        while not done:

           #env.render()
        
            # get the preprocessed game screen
            obs = preprocess_observation(obs)

            # feed the game screen and get the Q values for each action,  FEED THE NETWORK BY CALLING THE OUTPUT LAYER
            
            actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode:False})

            # get the action
            action = np.argmax(actions, axis=-1)
            actions_counter[str(action)] += 1 

            # select the action using epsilon greedy policy
            action = epsilon_greedy(action, global_step)
            
            # now perform the action and move to the next state, next_obs, receive reward
            next_obs, reward, done, _ = env.step(action)

            # Store this transistion as an experience in the replay buffer! Quite important
            exp_buffer.append([obs, action, preprocess_observation(next_obs), reward, done])
            
            # After certain steps, we train our Q network with samples from the experience replay buffer
            if global_step % steps_train == 0 and global_step > start_steps:
                
                # sample experience, mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]
                o_obs, o_act, o_next_obs, o_rew, o_done = sample_memories(batch_size)

                # states
                o_obs = [x for x in o_obs]

                # next states
                o_next_obs = [x for x in o_next_obs]

                # next actions
                next_act = mainQ_outputs.eval(feed_dict={X:o_next_obs, in_training_mode:False})


                # discounted reward: these are our Y-values
                y_batch = o_rew + discount_factor * np.max(next_act, axis=-1) * (1-o_done) 

                # merge all summaries and write to the file
                mrg_summary = merge_summary.eval(feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:False})
                file_writer.add_summary(mrg_summary, global_step)

                # To calculate the loss, we run the previously defined functions mentioned while feeding inputs
                train_loss, _ = sess.run([loss, training_op], feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:True})
                episodic_loss.append(train_loss)
            
            # after some interval we copy our main Q network weights to target Q network
            if (global_step+1) % copy_steps == 0 and global_step > start_steps:
                copy_target_to_main.run()
                
            obs = next_obs
            epoch += 1
            global_step += 1
            episodic_reward += reward
        
        history.append(episodic_reward)
        print('Epochs per episode:', epoch, 'Episode Reward:', episodic_reward,"Episode number:", len(history))
# Out:
# Epochs per episode: 635 Episode Reward: 230.0 Episode number: 1
# Epochs per episode: 500 Episode Reward: 140.0 Episode number: 2
# Epochs per episode: 671 Episode Reward: 240.0 Episode number: 3
# Epochs per episode: 643 Episode Reward: 220.0 Episode number: 4
# Epochs per episode: 1226 Episode Reward: 430.0 Episode number: 5
# Epochs per episode: 538 Episode Reward: 130.0 Episode number: 6
# Epochs per episode: 469 Episode Reward: 110.0 Episode number: 7
# Epochs per episode: 568 Episode Reward: 160.0 Episode number: 8
# Epochs per episode: 682 Episode Reward: 170.0 Episode number: 9
# Epochs per episode: 687 Episode Reward: 280.0 Episode number: 10

# %%
def last_episode(env):
  directory = './video'
  with tf.compat.v1.Session() as sess:
      init.run()
      # for each episode
      env = Recorder(env, directory)
      obs = env.reset()
      # while the state is not the terminal state
      terminal = False
      while not terminal:
          # get the preprocessed game screen
          obs = preprocess_observation(obs)

          # feed the game screen and get the Q values for each action,  FEED THE NETWORK BY CALLING THE OUTPUT LAYER
          actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode:False})

          # get the action
          action = np.argmax(actions, axis=-1)

          # select the action using epsilon greedy policy
          #action = epsilon_greedy(action, global_step)
          
          # now perform the action and move to the next state, next_obs, receive reward
          obs, reward, terminal, _ = env.step(action)

  return env

last_episode(env).play()
# Out:
# 100%|█████████▉| 843/844 [00:00<00:00, 1340.41it/s]
# <video autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video>
